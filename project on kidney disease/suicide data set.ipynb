# %%
import pandas as pd # data manipulation
import numpy as np #numerical computation,arrays
import matplotlib.pyplot as plt #plotting data & creating visualation
import seaborn as sms #plotting data & creating visualation
import plotly.express as px #plotting data & creating visualation
from plotly.subplots import make_subplots
from datetime import datetime

# %%
suicide_df =pd.read_csv("C:/project/Suicide dataset.csv")

# %%
suicide_df.head(10) # first 10 rows of data set
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
# 5  Albania  1987  female    75+ years            1       35600
# 6  Albania  1987  female  35-54 years            6      278800
# 7  Albania  1987  female  25-34 years            4      257200
# 8  Albania  1987    male  55-74 years            1      137500
# 9  Albania  1987  female   5-14 years            0      311000
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN     2,15,66,24,900
# 1               5.19  Albania1987           NaN     2,15,66,24,900
# 2               4.83  Albania1987           NaN     2,15,66,24,900
# ...

# %%
suicide_df.info()#information abt the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             27820 non-null  object
#  1   year                27820 non-null  int64
#  2   sex                 27820 non-null  object
#  3   age                 27820 non-null  object
#  4   suicides_no         27820 non-null  int64
#  5   population          27820 non-null  int64
#  6   suicides/100k pop   27820 non-null  float64
#  7   country-year        27820 non-null  object
#  8   HDI for year        8364 non-null   float64
#  9    gdp_for_year ($)   27820 non-null  object
#  10  gdp_per_capita ($)  27820 non-null  int64
#  11  generation          27820 non-null  object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 2.5+ MB

# %%
suicide_df.describe()#statitical operations
# Out:
#                year   suicides_no    population  suicides/100k pop  \
# count  27820.000000  27820.000000  2.782000e+04       27820.000000
# mean    2001.258375    242.574407  1.844794e+06          12.816097
# std        8.469055    902.047917  3.911779e+06          18.961511
# min     1985.000000      0.000000  2.780000e+02           0.000000
# 25%     1995.000000      3.000000  9.749850e+04           0.920000
# 50%     2002.000000     25.000000  4.301500e+05           5.990000
# 75%     2008.000000    131.000000  1.486143e+06          16.620000
# max     2016.000000  22338.000000  4.380521e+07         224.970000
#
#        HDI for year  gdp_per_capita ($)
# count   8364.000000        27820.000000
# mean       0.776601        16866.464414
# std        0.093367        18887.576472
# min        0.483000          251.000000
# 25%        0.713000         3447.000000
# 50%        0.779000         9372.000000
# 75%        0.855000        24874.000000
# ...

# %%
suicide_df.drop(["country-year"],inplace=True,axis=1) #dropping a columns
#1 column is dropped

# %%
suicide_df.head(10)#first 10 columns
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
# 5  Albania  1987  female    75+ years            1       35600
# 6  Albania  1987  female  35-54 years            6      278800
# 7  Albania  1987  female  25-34 years            4      257200
# 8  Albania  1987    male  55-74 years            1      137500
# 9  Albania  1987  female   5-14 years            0      311000
#
#    suicides/100k pop  HDI for year  gdp_for_year ($)   gdp_per_capita ($)  \
# 0               6.71           NaN     2,15,66,24,900                 796
# 1               5.19           NaN     2,15,66,24,900                 796
# ...

# %%
suicide_df.max()
# Out:
# country                    Uzbekistan
# year                             2016
# sex                              male
# age                         75+ years
# suicides_no                     22338
# population                   43805214
# suicides/100k pop              224.97
# HDI for year                    0.944
#  gdp_for_year ($)     99,88,65,77,331
# gdp_per_capita ($)             126352
# generation                     Silent
# dtype: object

# %%
suicide_df.min()
# Out:
# country                         Albania
# year                               1985
# sex                              female
# age                         15-24 years
# suicides_no                           0
# population                          278
# suicides/100k pop                   0.0
# HDI for year                      0.483
#  gdp_for_year ($)     1,00,16,39,95,151
# gdp_per_capita ($)                  251
# generation                      Boomers
# dtype: object

# %%
#fig = plt.figure(figsize=(16,9))

# %%
#plt.title("top 10 country with max suicide case",title)

# %%
plt.figure(figsize=(16,9))

plt.xlabel("ratio of suicide")
plt.ylabel("country")
plt.title("suicide rate vs country")
plt.show()

# %%
suicide_df.isnull().sum()# total null(0) values
# Out:
# country                   0
# year                      0
# sex                       0
# age                       0
# suicides_no               0
# population                0
# suicides/100k pop         0
# HDI for year          19456
#  gdp_for_year ($)         0
# gdp_per_capita ($)        0
# generation                0
# dtype: int64

# %%
suicide_df.shape #total numbers of columns and rows
# Out:
# (27820, 11)

# %%
suicide_df['HDI for year'].describe()
# Out:
# count    8364.000000
# mean        0.776601
# std         0.093367
# min         0.483000
# 25%         0.713000
# 50%         0.779000
# 75%         0.855000
# max         0.944000
# Name: HDI for year, dtype: float64

# %%
suicide_df.generation.unique()#what are the values inside generation column
# Out:
# array(['Generation X', 'Silent', 'G.I. Generation', 'Boomers',
#        'Millenials', 'Generation Z'], dtype=object)

# %%
#scatterplot of suicide no and year
plt.figure(figsize = (20,6))
sms.scatterplot(x = 'year' , y = 'suicides_no' , hue = 'generation', data =suicide_df )
plt.title('suicide no by year')
plt.show()

# %%
plt.figure(figsize = (10,25))
sms.countplot(y = 'country' , data=suicide_df , alpha = 0.7 )
plt.title('Data by country')
plt.show()

# %%
plt.figure(figsize = (10,6))
sms.countplot(x = 'sex' , data = suicide_df , alpha = 0.5)
plt.title('Data by Sex')
plt.show()

# %%
#suicide_df
plt.figure(figsize = (16,5))
sms.heatmap(suicide_df.corr() , annot = True)
plt.show()

# %%
sms.barplot(x = 'sex' , y  = 'suicides_no' , data = suicide_df)
plt.show()

# %%
sms.lineplot(x = 'year' , y = 'suicides_no' , data =suicide_df)
plt.show()

# %%
plt.figure(figsize = (13,6))
sms.barplot(x = 'generation' , y = 'suicides_no' , data = suicide_df)
plt.show()
